# %%
# %pip install pymupdf
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/Users/akshaypatade/Desktop/Projects/purchase-orders/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymupdf

# %%
doc = pymupdf.open("/Users/akshaypatade/Desktop/Projects/purchase-orders/Example POs/Hard - 2.pdf")
print(doc.metadata)
# Out:
# {'format': 'PDF 1.3', 'title': 'Hard', 'author': '', 'subject': '', 'keywords': '', 'creator': 'Pages', 'producer': 'macOS Version 14.5 (Build 23F79) Quartz PDFContext', 'creationDate': "D:20241114202324Z00'00'", 'modDate': "D:20241114202324Z00'00'", 'trapped': '', 'encryption': None}

# %%
page_one = doc[0]
find = page_one.find_tables()
print(find)
table1 = find.tables[0]

print(table1.extract())
# Out:
# ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[48], line 4
#       2 find = page_one.find_tables()
#       3 print(find)
# ----> 4 table1 = find.tables[0]
#       6 print(table1.extract())
#
# IndexError: list index out of range
